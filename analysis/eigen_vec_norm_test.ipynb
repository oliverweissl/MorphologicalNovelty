# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
mu = [0,0]
sigma = [[0.2,0.8],[0.2,0.2]]
n = 1000
x = np.random.multivariate_normal(mu, sigma, n).T
# Out:
# /tmp/ipykernel_16397/1453413609.py:4: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   x = np.random.multivariate_normal(mu, sigma, n).T

# %%
A = np.cov(x)

# %%
m = np.array([[1,2,3],[6,5,4]])
ms = m - m.mean(1).reshape(2,1)
np.dot(ms, ms.T)/2
# Out:
# array([[ 1., -1.],
#        [-1.,  1.]])

# %%
e, v = np.linalg.eig(A)

# %%
plt.scatter(x[0,:], x[1,:], alpha=0.2)
for e_, v_ in zip(e, v.T):
    plt.plot([0, 3*e_*v_[0]], [0, 3*e_*v_[1]], 'r-', lw=2)
plt.axis([-3,3,-3,3])
plt.title('Eigenvectors of covariance matrix scaled by eigenvalue.');

# %%
srt = np.argsort(-e)
e = e[srt]
v = v[srt]

# %%
ys = np.dot(np.linalg.inv(v).T, x)

# %%
plt.scatter(ys[0,:], ys[1,:], alpha=0.2)
for e_, v_ in zip(e, np.eye(2)):
    plt.plot([0, 3*e_*v_[0]], [0, 3*e_*v_[1]], 'r-', lw=2)
plt.axis([-3,3,-3,3]);

# %%
ys = np.dot(v.T, ys)
plt.scatter(ys[0,:], ys[1,:], alpha=0.2)
for e_, v_ in zip(e, np.eye(2)):
    plt.plot([0, 3*e_*v_[0]], [0, 3*e_*v_[1]], 'r-', lw=2)
plt.axis([-3,3,-3,3]);
