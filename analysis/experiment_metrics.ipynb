# %%
from experiment import optimize

# %%
tests = ['yates-chi-squared','chi-squared','hellinger-dist','manhattan-dist','euclidian-dist','chybyshev-dist','pcc', 'minkowsky-dist']
p = [x/10 for x in list((10,60,2))]

for test in tests:
    if test == "minkowsky-dist":
        for p_val in p:
            await optimize.main((test,p_val))
        continue
    await optimize.main((test,None))
# Out:
# [2023-03-24 13:33:14,668] [INFO] [optimize] Starting optimization
# [2023-03-24 13:33:14,744] [INFO] [optimize] Starting optimization process..
# [2023-03-24 13:33:15,189] [INFO] [_local_runner] Starting simulation batch with mujoco.
# [2023-03-24 13:33:15,199] [INFO] [_local_runner] Environment 0
# [2023-03-24 13:33:15,578] [INFO] [_local_runner] Environment 1
# [2023-03-24 13:33:16,017] [INFO] [_local_runner] Environment 2
# [2023-03-24 13:33:16,501] [INFO] [_local_runner] Environment 3
# [2023-03-24 13:33:16,854] [INFO] [_local_runner] Environment 4
# [2023-03-24 13:33:17,084] [INFO] [_local_runner] Environment 5
# [2023-03-24 13:33:17,582] [INFO] [_local_runner] Environment 6
# [2023-03-24 13:33:17,898] [INFO] [_local_runner] Environment 7
# [2023-03-24 13:33:18,167] [INFO] [_local_runner] Environment 8
# [2023-03-24 13:33:18,931] [INFO] [_local_runner] Environment 9
# [2023-03-24 13:33:19,282] [INFO] [_local_runner] Environment 10
# ...
