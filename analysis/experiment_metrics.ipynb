# %%
from glob import glob
from plotting import EAPlots
from experiment import optimize

# %%
#ran_tests= ['chybyshev-dist','yates-chi-squared','chi-squared','hellinger-dist','manhattan-dist','euclidian-dist','chybyshev-dist','pcc','minkowsky-dist']
#tests = ["wasserstein-dist"]
#p = [x/10 for x in list(range(10,60,5))]

# %%
await optimize.main()
# Out:
# [2023-03-27 20:44:40,108] [INFO] [optimize] Starting optimization
# [2023-03-27 20:44:40,333] [INFO] [optimize] Starting optimization process..
# [2023-03-27 20:44:43,230] [INFO] [_local_runner] Starting simulation batch with mujoco.
# [2023-03-27 20:44:43,240] [INFO] [_local_runner] Environment 0
# [2023-03-27 20:44:43,621] [INFO] [_local_runner] Environment 1
# [2023-03-27 20:44:43,991] [INFO] [_local_runner] Environment 2
# [2023-03-27 20:44:44,475] [INFO] [_local_runner] Environment 3
# [2023-03-27 20:44:44,829] [INFO] [_local_runner] Environment 4
# [2023-03-27 20:44:45,065] [INFO] [_local_runner] Environment 5
# [2023-03-27 20:44:45,563] [INFO] [_local_runner] Environment 6
# [2023-03-27 20:44:45,966] [INFO] [_local_runner] Environment 7
# [2023-03-27 20:44:46,237] [INFO] [_local_runner] Environment 8
# [2023-03-27 20:44:47,010] [INFO] [_local_runner] Environment 9
# [2023-03-27 20:44:47,360] [INFO] [_local_runner] Environment 10
# ...

# %%
#cv-corrl cv-chi cv-inters cv-bha

dbs = glob("experiments/*")

EAPlots.plot_bricks_hinges("experiments/database")
EAPlots.plot_novelty_from_db("experiments/database")
#EAPlots.plot_novelty(db, novelty_test=('yates-chi-squared', None))

# %%
# Out:
#      id       db_id  offspring_size genotype_table fitness_table  \
# 0     1  optmodular              30       genotype         float
# 1     1  optmodular              30       genotype         float
# 2     1  optmodular              30       genotype         float
# 3     1  optmodular              30       genotype         float
# 4     1  optmodular              30       genotype         float
# ..   ..         ...             ...            ...           ...
# 195   1  optmodular              30       genotype         float
# 196   1  optmodular              30       genotype         float
# 197   1  optmodular              30       genotype         float
# 198   1  optmodular              30       genotype         float
# 199   1  optmodular              30       genotype         float
#
#     novelty_table  ea_optimizer_id  generation_index  individual_index  \
# 0           float                1                 0                 0
# ...
