# %%
from glob import glob
from plotting import EAPlots
from experiment import optimize
# Out:
# ---------------------------------------------------------------------------
# JuliaError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 from glob import glob
# ----> 2 from plotting import EAPlots
#       3 from experiment import optimize
#
# File ~/Thesis/analysis/plotting.py:8
#       5 import pandas as pd
#       7 from numpy import std
# ----> 8 from common.phenotype_framework import PhenotypeFramework as pf
#       9 from common.phenotype_framework import PhenotypeFramework
#      10 from revolve2.core.optimization import DbId
#
# File ~/Thesis/common/phenotype_framework.py:20
#      18 jl = Julia(compiled_modules=False)
#      19 from julia import Main
# ---> 20 jl.eval('include("~/Theis/common/calc_novelty.jl")')
#      23 class PhenotypeFramework:
#      24     @classmethod
#      25     def get_bricks_hinges_amount(cls, genotype: Genotype | str) -> (int, int):
#
# File ~/.local/lib/python3.10/site-packages/julia/core.py:627, in Julia.eval(self, src)
#     625 if src is None:
#     626     return None
# --> 627 ans = self._call(src)
#     628 if not ans:
#     629     return None
#
# File ~/.local/lib/python3.10/site-packages/julia/core.py:555, in Julia._call(self, src)
#     553 # logger.debug("_call(%s)", src)
#     554 ans = self.api.jl_eval_string(src.encode('utf-8'))
# --> 555 self.check_exception(src)
#     557 return ans
#
# File ~/.local/lib/python3.10/site-packages/julia/core.py:609, in Julia.check_exception(self, src)
#     607 else:
#     608     exception = sprint(showerror, self._as_pyobj(res))
# --> 609 raise JuliaError(u'Exception \'{}\' occurred while calling julia code:\n{}'
#     610                  .format(exception, src))
#
# JuliaError: Exception 'SystemError: opening file "/home/oliver/Thesis/analysis/~/Theis/common/calc_novelty.jl": No such file or directory' occurred while calling julia code:
# include("~/Theis/common/calc_novelty.jl")

# %%
a = [x / 10 for x in list(range(0, 10, 2))]

await optimize.main(novelty_search=False)

for a_v in a:
    await optimize.main(novelty_search=True, novelty_weight=a_v)

# %%
#cv-corrl cv-chi cv-inters cv-bha

dbs = glob("/media/oliver/DC7282EC7282CB2A/Users/olive/Desktop/thesis/experiments/*")

for db in [dbs[-1]]:
    EAPlots.plot_bricks_hinges(db)
    EAPlots.plot_novelty_from_db(db)
#EAPlots.plot_novelty(db, novelty_test=('yates-chi-squared', None))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 6
#       3 dbs = glob("/media/oliver/DC7282EC7282CB2A/Users/olive/Desktop/thesis/experiments/*")
#       5 for db in dbs:
# ----> 6     EAPlots.plot_bricks_hinges(db)
#       7     EAPlots.plot_novelty_from_db(db)
#       8 #EAPlots.plot_novelty(db, novelty_test=('yates-chi-squared', None))
#
# File ~/Thesis/analysis/plotting.py:31, in EAPlots.plot_bricks_hinges(cls, database, db_id, *_)
#      22 @classmethod
#      23 def plot_bricks_hinges(cls, database: str, db_id: DbId = DbId("optmodular"), *_) -> None:
#      24     """
#      25     Plot fitness as described at the top of this file.
#      26
#      27     :param database: Database where the data is stored.
#      28     :param db_id: Id of the evolutionary process to plot.
#      29     """
# ---> 31     df = load_db(database, db_id)
#      33     df["bricks"], df["hinges"] = zip(*df.serialized_multineat_genome.apply(PhenotypeFramework.get_bricks_hinges_amount))
#      35     # calculate max min avg
#
# File ~/Thesis/analysis/_load_db.py:16, in load_db(database, db_id)
#      14 def load_db(database: str, db_id: DbId = DbId("optmodular")) -> pd.DataFrame:
#      15     # open the database
# ---> 16     db = open_database_sqlite(database)
#      17     # read the optimizer data into a pandas dataframe
#      19     df = pd.read_sql(
#      20         select(
#      21             DbEAOptimizer,
#    (...)
#      40         db,
#      41     )
#
# File ~/.local/lib/python3.10/site-packages/revolve2/core/database/_sqlite.py:42, in open_database_sqlite(db_root_directory, create)
#      39 dburl = f"sqlite:///{dbpath}"
#      41 if not create and not os.path.exists(dbpath):
# ---> 42     raise RuntimeError(f"Trying to open database but it does not exist: {dbpath}")
#      44 os.makedirs(db_root_directory, exist_ok=True)
#      45 return create_engine(dburl)
#
# RuntimeError: Trying to open database but it does not exist: /media/oliver/DC7282EC7282CB2A/Users/olive/Desktop/thesis/experiments/n_0.0_fitness.png/db.sqlite

# %%
# Out:
#      id       db_id  offspring_size genotype_table fitness_table  \
# 0     1  optmodular              30       genotype         float
# 1     1  optmodular              30       genotype         float
# 2     1  optmodular              30       genotype         float
# 3     1  optmodular              30       genotype         float
# 4     1  optmodular              30       genotype         float
# ..   ..         ...             ...            ...           ...
# 195   1  optmodular              30       genotype         float
# 196   1  optmodular              30       genotype         float
# 197   1  optmodular              30       genotype         float
# 198   1  optmodular              30       genotype         float
# 199   1  optmodular              30       genotype         float
#
#     novelty_table  ea_optimizer_id  generation_index  individual_index  \
# 0           float                1                 0                 0
# 1           float                1                 0                 1
# 2           float                1                 0                 2
# 3           float                1                 0                 3
# 4           float                1                 0                 4
# ..            ...              ...               ...               ...
# 195         float                1                10                15
# 196         float                1                10                16
# 197         float                1                10                17
# 198         float                1                10                18
# 199         float                1                10                19
#
#      individual_id  ...  genotype_id  fitness_id  novelty_id  id_1  \
# 0                0  ...            1           1          21     1
# 1                1  ...            2           2          22     2
# 2                2  ...            3           3          23     3
# 3                3  ...            4           4          24     4
# 4                4  ...            5           5          25     5
# ..             ...  ...          ...         ...         ...   ...
# 195            195  ...          196         376         396   376
# 196            196  ...          197         377         397   377
# 197            197  ...          198         378         398   378
# 198            198  ...          199         379         399   379
# 199            199  ...          200         380         400   380
#
#                            serialized_multineat_genome  id_2 body_id  \
# 0    {\n    "value0": {\n        "value0": 0,\n    ...     1       1
# 1    {\n    "value0": {\n        "value0": 0,\n    ...     2       2
# 2    {\n    "value0": {\n        "value0": 0,\n    ...     3       3
# 3    {\n    "value0": {\n        "value0": 0,\n    ...     4       4
# 4    {\n    "value0": {\n        "value0": 0,\n    ...     5       5
# ..                                                 ...   ...     ...
# 195  {\n    "value0": {\n        "value0": 0,\n    ...   196     376
# 196  {\n    "value0": {\n        "value0": 0,\n    ...   197     377
# 197  {\n    "value0": {\n        "value0": 0,\n    ...   198     378
# 198  {\n    "value0": {\n        "value0": 0,\n    ...   199     379
# 199  {\n    "value0": {\n        "value0": 0,\n    ...   200     380
#
#      brain_id  id_3     value
# 0          21    21  0.346180
# 1          22    22  0.885624
# 2          23    23  0.216302
# 3          24    24  0.619040
# 4          25    25  1.000000
# ..        ...   ...       ...
# 195       396   396  0.474029
# 196       397   397  0.155372
# 197       398   398  0.336848
# 198       399   399  0.322685
# 199       400   400  0.298027
#
# [200 rows x 22 columns]
